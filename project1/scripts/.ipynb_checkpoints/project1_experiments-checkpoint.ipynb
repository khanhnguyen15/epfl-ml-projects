# %%
# Useful starting lines
# %matplotlib inline
import numpy as np
import matplotlib.pyplot as plt
# %load_ext autoreload
# %autoreload 2

# %%
from data_preprocessing import *
from implementation import *
from helpers import *
from plot import *

# %%
from proj1_helpers import *
DATA_TRAIN_PATH = '../data/train.csv' # TODO: download train data and supply path here 
y, tX, ids = load_csv_data(DATA_TRAIN_PATH)

# %% [markdown]
# ### Using pandas to see the pattern in the data. Note that the use of pandas is not included in other analysis and only for understanding the dataset purposes.

# %%
import pandas as pd
data = pd.read_csv(DATA_TRAIN_PATH)
data.head()
# Out:
#        Id Prediction  DER_mass_MMC  DER_mass_transverse_met_lep  DER_mass_vis  \
# 0  100000          s       138.470                       51.655        97.827
# 1  100001          b       160.937                       68.768       103.235
# 2  100002          b      -999.000                      162.172       125.953
# 3  100003          b       143.905                       81.417        80.943
# 4  100004          b       175.864                       16.915       134.805
#
#    DER_pt_h  DER_deltaeta_jet_jet  DER_mass_jet_jet  DER_prodeta_jet_jet  \
# 0    27.980                  0.91           124.711                2.666
# 1    48.146               -999.00          -999.000             -999.000
# 2    35.635               -999.00          -999.000             -999.000
# 3     0.414               -999.00          -999.000             -999.000
# 4    16.405               -999.00          -999.000             -999.000
#
#    DER_deltar_tau_lep  ...  PRI_met_phi  PRI_met_sumet  PRI_jet_num  \
# 0               3.064  ...       -0.277        258.733            2
# 1               3.473  ...       -1.916        164.546            1
# 2               3.148  ...       -2.186        260.414            1
# 3               3.310  ...        0.060         86.062            0
# 4               3.891  ...       -0.871         53.131            0
#
#    PRI_jet_leading_pt  PRI_jet_leading_eta  PRI_jet_leading_phi  \
# 0              67.435                2.150                0.444
# 1              46.226                0.725                1.158
# 2              44.251                2.053               -2.028
# 3            -999.000             -999.000             -999.000
# 4            -999.000             -999.000             -999.000
#
#    PRI_jet_subleading_pt  PRI_jet_subleading_eta  PRI_jet_subleading_phi  \
# 0                 46.062                    1.24                  -2.475
# 1               -999.000                 -999.00                -999.000
# 2               -999.000                 -999.00                -999.000
# 3               -999.000                 -999.00                -999.000
# 4               -999.000                 -999.00                -999.000
#
#    PRI_jet_all_pt
# 0         113.497
# 1          46.226
# 2          44.251
# 3           0.000
# 4           0.000
#
# [5 rows x 32 columns]

# %%
data['PRI_jet_num'].describe()
# Out:
# count    250000.000000
# mean          0.979176
# std           0.977426
# min           0.000000
# 25%           0.000000
# 50%           1.000000
# 75%           2.000000
# max           3.000000
# Name: PRI_jet_num, dtype: float64

# %%
data['Prediction'] = [1 if x == 's' else 0 for x in data['Prediction']]

# %%
data_0 = data[data['PRI_jet_num'] == 0]
data_1 = data[data['PRI_jet_num'] == 1]
data_2 = data[data['PRI_jet_num'] == 2]
data_3 = data[data['PRI_jet_num'] == 3]

# %%
data_0.describe()
# Out:
#                   Id    Prediction  DER_mass_MMC  DER_mass_transverse_met_lep  \
# count   99913.000000  99913.000000  99913.000000                 99913.000000
# mean   224892.549558      0.255142   -172.077816                    58.786239
# std     72138.199984      0.435943    494.022274                    32.003551
# min    100003.000000      0.000000   -999.000000                     0.002000
# 25%    162434.000000      0.000000   -999.000000                    35.062000
# 50%    224898.000000      0.000000     96.528000                    62.144000
# 75%    287392.000000      1.000000    126.793000                    79.650000
# max    349999.000000      1.000000    863.647000                   570.115000
#
#        DER_mass_vis      DER_pt_h  DER_deltaeta_jet_jet  DER_mass_jet_jet  \
# count  99913.000000  99913.000000               99913.0           99913.0
# mean      81.870309     13.823867                -999.0            -999.0
# std       38.043669     16.674707                   0.0               0.0
# min        7.120000      0.000000                -999.0            -999.0
# 25%       60.947000      2.275000                -999.0            -999.0
# 50%       75.533000      6.677000                -999.0            -999.0
# 75%       94.135000     24.202000                -999.0            -999.0
# max     1349.351000   2834.999000                -999.0            -999.0
#
#        DER_prodeta_jet_jet  DER_deltar_tau_lep  ...   PRI_met_phi  \
# count              99913.0        99913.000000  ...  99913.000000
# mean                -999.0            2.664961  ...     -0.024443
# std                    0.0            0.693295  ...      1.811006
# min                 -999.0            0.277000  ...     -3.142000
# 25%                 -999.0            2.338000  ...     -1.583000
# 50%                 -999.0            2.822000  ...     -0.051000
# 75%                 -999.0            3.095000  ...      1.546000
# max                 -999.0            5.684000  ...      3.142000
#
#        PRI_met_sumet  PRI_jet_num  PRI_jet_leading_pt  PRI_jet_leading_eta  \
# count    99913.00000      99913.0             99913.0              99913.0
# mean       125.86081          0.0              -999.0               -999.0
# std         53.08660          0.0                 0.0                  0.0
# min         13.67800          0.0              -999.0               -999.0
# 25%         87.95100          0.0              -999.0               -999.0
# 50%        119.47900          0.0              -999.0               -999.0
# 75%        156.41800          0.0              -999.0               -999.0
# max       1391.52900          0.0              -999.0               -999.0
#
#        PRI_jet_leading_phi  PRI_jet_subleading_pt  PRI_jet_subleading_eta  \
# count              99913.0                99913.0                 99913.0
# mean                -999.0                 -999.0                  -999.0
# std                    0.0                    0.0                     0.0
# min                 -999.0                 -999.0                  -999.0
# 25%                 -999.0                 -999.0                  -999.0
# 50%                 -999.0                 -999.0                  -999.0
# 75%                 -999.0                 -999.0                  -999.0
# max                 -999.0                 -999.0                  -999.0
#
#        PRI_jet_subleading_phi  PRI_jet_all_pt
# count                 99913.0         99913.0
# mean                   -999.0             0.0
# std                       0.0             0.0
# min                    -999.0             0.0
# 25%                    -999.0             0.0
# 50%                    -999.0             0.0
# 75%                    -999.0             0.0
# max                    -999.0             0.0
#
# [8 rows x 32 columns]

# %%
data_0
# Out:
#             Id  Prediction  DER_mass_MMC  DER_mass_transverse_met_lep  \
# 3       100003           0       143.905                       81.417
# 4       100004           0       175.864                       16.915
# 8       100008           0       105.594                       50.559
# 10      100010           0      -999.000                       86.240
# 13      100013           0        82.488                       31.663
# ...        ...         ...           ...                          ...
# 249990  349990           0       127.822                       82.865
# 249995  349995           0      -999.000                       71.989
# 249996  349996           0      -999.000                       58.179
# 249998  349998           0        94.951                       19.362
# 249999  349999           0      -999.000                       72.756
#
#         DER_mass_vis  DER_pt_h  DER_deltaeta_jet_jet  DER_mass_jet_jet  \
# 3             80.943     0.414                -999.0            -999.0
# 4            134.805    16.405                -999.0            -999.0
# 8            100.989     4.288                -999.0            -999.0
# 10            79.692    27.201                -999.0            -999.0
# 13            64.128     8.232                -999.0            -999.0
# ...              ...       ...                   ...               ...
# 249990       100.024     0.860                -999.0            -999.0
# 249995        36.548     5.042                -999.0            -999.0
# 249996        68.083    22.439                -999.0            -999.0
# 249998        68.812    13.504                -999.0            -999.0
# 249999        70.831     7.479                -999.0            -999.0
#
#         DER_prodeta_jet_jet  DER_deltar_tau_lep  ...  PRI_met_phi  \
# 3                    -999.0               3.310  ...        0.060
# 4                    -999.0               3.891  ...       -0.871
# 8                    -999.0               2.904  ...        0.024
# 10                   -999.0               2.338  ...        0.688
# 13                   -999.0               2.823  ...        1.433
# ...                     ...                 ...  ...          ...
# 249990               -999.0               3.210  ...        2.674
# 249995               -999.0               1.392  ...        2.859
# 249996               -999.0               2.585  ...       -0.867
# 249998               -999.0               3.365  ...        0.811
# 249999               -999.0               2.025  ...       -1.596
#
#         PRI_met_sumet  PRI_jet_num  PRI_jet_leading_pt  PRI_jet_leading_eta  \
# 3              86.062            0              -999.0               -999.0
# 4              53.131            0              -999.0               -999.0
# 8             129.804            0              -999.0               -999.0
# 10            250.178            0              -999.0               -999.0
# 13            163.420            0              -999.0               -999.0
# ...               ...          ...                 ...                  ...
# 249990        120.320            0              -999.0               -999.0
# 249995        144.665            0              -999.0               -999.0
# 249996         80.408            0              -999.0               -999.0
# 249998        112.718            0              -999.0               -999.0
# 249999         99.405            0              -999.0               -999.0
#
#         PRI_jet_leading_phi  PRI_jet_subleading_pt  PRI_jet_subleading_eta  \
# 3                    -999.0                 -999.0                  -999.0
# 4                    -999.0                 -999.0                  -999.0
# 8                    -999.0                 -999.0                  -999.0
# 10                   -999.0                 -999.0                  -999.0
# 13                   -999.0                 -999.0                  -999.0
# ...                     ...                    ...                     ...
# 249990               -999.0                 -999.0                  -999.0
# 249995               -999.0                 -999.0                  -999.0
# 249996               -999.0                 -999.0                  -999.0
# 249998               -999.0                 -999.0                  -999.0
# 249999               -999.0                 -999.0                  -999.0
#
#         PRI_jet_subleading_phi  PRI_jet_all_pt
# 3                       -999.0             0.0
# 4                       -999.0             0.0
# 8                       -999.0             0.0
# 10                      -999.0             0.0
# 13                      -999.0             0.0
# ...                        ...             ...
# 249990                  -999.0             0.0
# 249995                  -999.0             0.0
# 249996                  -999.0             0.0
# 249998                  -999.0             0.0
# 249999                  -999.0             0.0
#
# [99913 rows x 32 columns]

# %%
data_0 = data_0.loc[:, np.array(data_0.describe().loc['mean'] != -999)]

# %%
data_0.describe()
# Out:
#                   Id    Prediction  DER_mass_MMC  DER_mass_transverse_met_lep  \
# count   99913.000000  99913.000000  99913.000000                 99913.000000
# mean   224892.549558      0.255142   -172.077816                    58.786239
# std     72138.199984      0.435943    494.022274                    32.003551
# min    100003.000000      0.000000   -999.000000                     0.002000
# 25%    162434.000000      0.000000   -999.000000                    35.062000
# 50%    224898.000000      0.000000     96.528000                    62.144000
# 75%    287392.000000      1.000000    126.793000                    79.650000
# max    349999.000000      1.000000    863.647000                   570.115000
#
#        DER_mass_vis      DER_pt_h  DER_deltar_tau_lep    DER_pt_tot  \
# count  99913.000000  99913.000000        99913.000000  99913.000000
# mean      81.870309     13.823867            2.664961     13.823867
# std       38.043669     16.674707            0.693295     16.674707
# min        7.120000      0.000000            0.277000      0.000000
# 25%       60.947000      2.275000            2.338000      2.275000
# 50%       75.533000      6.677000            2.822000      6.677000
# 75%       94.135000     24.202000            3.095000     24.202000
# max     1349.351000   2834.999000            5.684000   2834.999000
#
#          DER_sum_pt  DER_pt_ratio_lep_tau  ...   PRI_tau_eta   PRI_tau_phi  \
# count  99913.000000          99913.000000  ...  99913.000000  99913.000000
# mean      76.377011              1.392763  ...     -0.024858     -0.015657
# std       23.561057              0.581596  ...      1.233430      1.817351
# min       46.104000              0.127000  ...     -2.499000     -3.142000
# 25%       61.297000              0.968000  ...     -0.960000     -1.586000
# 50%       71.586000              1.318000  ...     -0.043000     -0.049000
# 75%       85.242000              1.728000  ...      0.900000      1.556000
# max     1324.678000             10.571000  ...      2.494000      3.142000
#
#          PRI_lep_pt   PRI_lep_eta   PRI_lep_phi       PRI_met   PRI_met_phi  \
# count  99913.000000  99913.000000  99913.000000  99913.000000  99913.000000
# mean      42.364287     -0.052311      0.042352     31.536761     -0.024443
# std       14.585979      1.310855      1.817844     20.294541      1.811006
# min       26.000000     -2.505000     -3.142000      0.109000     -3.142000
# 25%       31.863000     -1.121000     -1.526000     18.001000     -1.583000
# 50%       38.969000     -0.104000      0.085000     29.538000     -0.051000
# 75%       49.007000      0.989000      1.621000     42.273000      1.546000
# max      560.271000      2.503000      3.142000   2842.617000      3.142000
#
#        PRI_met_sumet  PRI_jet_num  PRI_jet_all_pt
# count    99913.00000      99913.0         99913.0
# mean       125.86081          0.0             0.0
# std         53.08660          0.0             0.0
# min         13.67800          0.0             0.0
# 25%         87.95100          0.0             0.0
# 50%        119.47900          0.0             0.0
# 75%        156.41800          0.0             0.0
# max       1391.52900          0.0             0.0
#
# [8 rows x 22 columns]

# %%
data_1.describe()
# Out:
#                   Id    Prediction  DER_mass_MMC  DER_mass_transverse_met_lep  \
# count   77544.000000  77544.000000  77544.000000                  77544.00000
# mean   225144.066040      0.357346     12.845744                     46.05360
# std     72137.275981      0.479221    337.359355                     35.58119
# min    100001.000000      0.000000   -999.000000                      0.00000
# 25%    162817.750000      0.000000     84.531750                     16.26750
# 50%    225049.500000      0.000000    107.934500                     40.49850
# 75%    287516.500000      1.000000    132.932500                     70.01300
# max    349997.000000      1.000000   1192.026000                    571.86800
#
#        DER_mass_vis      DER_pt_h  DER_deltaeta_jet_jet  DER_mass_jet_jet  \
# count  77544.000000  77544.000000               77544.0           77544.0
# mean      82.219033     65.903090                -999.0            -999.0
# std       42.288122     47.431007                   0.0               0.0
# min        6.329000      0.000000                -999.0            -999.0
# 25%       59.809750     37.131000                -999.0            -999.0
# 50%       73.936000     53.081000                -999.0            -999.0
# 75%       92.679750     79.002000                -999.0            -999.0
# max      959.601000    753.745000                -999.0            -999.0
#
#        DER_prodeta_jet_jet  DER_deltar_tau_lep  ...   PRI_met_phi  \
# count              77544.0        77544.000000  ...  77544.000000
# mean                -999.0            2.339686  ...     -0.005579
# std                    0.0            0.737633  ...      1.811937
# min                 -999.0            0.208000  ...     -3.141000
# 25%                 -999.0            1.855000  ...     -1.579000
# 50%                 -999.0            2.404000  ...     -0.011000
# 75%                 -999.0            2.855000  ...      1.568000
# max                 -999.0            5.655000  ...      3.142000
#
#        PRI_met_sumet  PRI_jet_num  PRI_jet_leading_pt  PRI_jet_leading_eta  \
# count   77544.000000      77544.0        77544.000000         77544.000000
# mean      203.324833          1.0           65.012163            -0.000800
# std        81.901141          0.0           45.154510             1.821593
# min        21.066000          1.0           30.000000            -4.499000
# 25%       148.362000          1.0           37.529000            -1.346000
# 50%       189.476000          1.0           49.974000            -0.002000
# 75%       240.657750          1.0           74.592250             1.347000
# max      1383.552000          1.0          743.222000             4.492000
#
#        PRI_jet_leading_phi  PRI_jet_subleading_pt  PRI_jet_subleading_eta  \
# count         77544.000000                77544.0                 77544.0
# mean             -0.015052                 -999.0                  -999.0
# std               1.817529                    0.0                     0.0
# min              -3.142000                 -999.0                  -999.0
# 25%              -1.594000                 -999.0                  -999.0
# 50%              -0.039000                 -999.0                  -999.0
# 75%               1.564000                 -999.0                  -999.0
# max               3.141000                 -999.0                  -999.0
#
#        PRI_jet_subleading_phi  PRI_jet_all_pt
# count                 77544.0    77544.000000
# mean                   -999.0       65.012163
# std                       0.0       45.154510
# min                    -999.0       30.000000
# 25%                    -999.0       37.529000
# 50%                    -999.0       49.974000
# 75%                    -999.0       74.592250
# max                    -999.0      743.222000
#
# [8 rows x 32 columns]

# %%
data_1 = data_1.loc[:, np.array(data_1.describe().loc['mean'] != -999)]

# %%
data_1.describe()
# Out:
#                   Id    Prediction  DER_mass_MMC  DER_mass_transverse_met_lep  \
# count   77544.000000  77544.000000  77544.000000                  77544.00000
# mean   225144.066040      0.357346     12.845744                     46.05360
# std     72137.275981      0.479221    337.359355                     35.58119
# min    100001.000000      0.000000   -999.000000                      0.00000
# 25%    162817.750000      0.000000     84.531750                     16.26750
# 50%    225049.500000      0.000000    107.934500                     40.49850
# 75%    287516.500000      1.000000    132.932500                     70.01300
# max    349997.000000      1.000000   1192.026000                    571.86800
#
#        DER_mass_vis      DER_pt_h  DER_deltar_tau_lep    DER_pt_tot  \
# count  77544.000000  77544.000000        77544.000000  77544.000000
# mean      82.219033     65.903090            2.339686     16.645000
# std       42.288122     47.431007            0.737633     17.007924
# min        6.329000      0.000000            0.208000      0.000000
# 25%       59.809750     37.131000            1.855000      2.895000
# 50%       73.936000     53.081000            2.404000     10.705000
# 75%       92.679750     79.002000            2.855000     26.214250
# max      959.601000    753.745000            5.655000    330.527000
#
#          DER_sum_pt  DER_pt_ratio_lep_tau  ...   PRI_lep_eta   PRI_lep_phi  \
# count  77544.000000          77544.000000  ...  77544.000000  77544.000000
# mean     150.368035              1.444185  ...      0.006686      0.044894
# std       65.182087              0.846425  ...      1.262214      1.815456
# min       77.017000              0.083000  ...     -2.494000     -3.142000
# 25%      110.752750              0.867750  ...     -0.975000     -1.522000
# 50%      132.326500              1.268000  ...      0.016000      0.094000
# 75%      167.624000              1.797000  ...      0.984250      1.618250
# max     1214.932000             16.776000  ...      2.502000      3.142000
#
#             PRI_met   PRI_met_phi  PRI_met_sumet  PRI_jet_num  \
# count  77544.000000  77544.000000   77544.000000      77544.0
# mean      40.123371     -0.005579     203.324833          1.0
# std       28.357324      1.811937      81.901141          0.0
# min        0.251000     -3.141000      21.066000          1.0
# 25%       21.800750     -1.579000     148.362000          1.0
# 50%       34.568500     -0.011000     189.476000          1.0
# 75%       51.069000      1.568000     240.657750          1.0
# max      536.468000      3.142000    1383.552000          1.0
#
#        PRI_jet_leading_pt  PRI_jet_leading_eta  PRI_jet_leading_phi  \
# count        77544.000000         77544.000000         77544.000000
# mean            65.012163            -0.000800            -0.015052
# std             45.154510             1.821593             1.817529
# min             30.000000            -4.499000            -3.142000
# 25%             37.529000            -1.346000            -1.594000
# 50%             49.974000            -0.002000            -0.039000
# 75%             74.592250             1.347000             1.564000
# max            743.222000             4.492000             3.141000
#
#        PRI_jet_all_pt
# count    77544.000000
# mean        65.012163
# std         45.154510
# min         30.000000
# 25%         37.529000
# 50%         49.974000
# 75%         74.592250
# max        743.222000
#
# [8 rows x 25 columns]

# %%
data_2.describe()
# Out:
#                   Id    Prediction  DER_mass_MMC  DER_mass_transverse_met_lep  \
# count   50379.000000  50379.000000  50379.000000                 50379.000000
# mean   225129.697374      0.510808     56.928924                    38.343612
# std     72182.186996      0.499888    268.937491                    35.273944
# min    100000.000000      0.000000   -999.000000                     0.000000
# 25%    162596.500000      0.000000     91.593500                    11.605500
# 50%    225414.000000      1.000000    112.991000                    28.501000
# 75%    287655.500000      1.000000    132.447500                    56.512000
# max    349994.000000      1.000000    966.986000                   595.819000
#
#        DER_mass_vis      DER_pt_h  DER_deltaeta_jet_jet  DER_mass_jet_jet  \
# count  50379.000000  50379.000000          50379.000000      50379.000000
# mean      79.213348    102.985028              2.606534        391.406450
# std       39.917128     70.529284              1.812621        426.852418
# min        7.330000      0.120000              0.000000         13.602000
# 25%       58.525000     54.065500              0.984000        106.676000
# 50%       72.270000     87.682000              2.383000        228.643000
# 75%       89.505500    134.134500              4.004000        513.674500
# max     1051.358000   1053.807000              8.503000       4974.979000
#
#        DER_prodeta_jet_jet  DER_deltar_tau_lep  ...   PRI_met_phi  \
# count         50379.000000        50379.000000  ...  50379.000000
# mean             -1.115458            2.060607  ...      0.003340
# std               3.821072            0.759354  ...      1.814845
# min             -18.066000            0.228000  ...     -3.142000
# 25%              -3.251000            1.485000  ...     -1.560500
# 50%              -0.465000            2.020000  ...     -0.003000
# 75%               0.869000            2.632000  ...      1.576000
# max              16.690000            5.579000  ...      3.142000
#
#        PRI_met_sumet  PRI_jet_num  PRI_jet_leading_pt  PRI_jet_leading_eta  \
# count   50379.000000      50379.0        50379.000000         50379.000000
# mean      296.011170          2.0           98.470208            -0.002448
# std       111.483795          0.0           61.866979             1.814152
# min        34.323000          2.0           30.196000            -4.497000
# 25%       220.219000          2.0           56.617500            -1.416000
# 50%       274.747000          2.0           80.543000             0.015000
# 75%       346.437000          2.0          120.356000             1.403000
# max      1364.632000          2.0         1120.573000             4.499000
#
#        PRI_jet_leading_phi  PRI_jet_subleading_pt  PRI_jet_subleading_eta  \
# count         50379.000000           50379.000000            50379.000000
# mean             -0.013290              51.709866               -0.013631
# std               1.809918              25.460068                2.134823
# min              -3.142000              30.000000               -4.500000
# 25%              -1.578000              35.245500               -1.757000
# 50%              -0.032000              43.551000               -0.013000
# 75%               1.553000              58.712500                1.725000
# max               3.141000             464.262000                4.500000
#
#        PRI_jet_subleading_phi  PRI_jet_all_pt
# count            50379.000000    50379.000000
# mean                 0.006144      150.180076
# std                  1.817867       77.646249
# min                 -3.142000       60.223000
# 25%                 -1.568500       96.911500
# 50%                  0.012000      128.486000
# 75%                  1.589000      179.995500
# max                  3.142000     1173.613000
#
# [8 rows x 32 columns]

# %%
data_3.describe()
# Out:
#                   Id    Prediction  DER_mass_MMC  DER_mass_transverse_met_lep  \
# count   22164.000000  22164.000000  22164.000000                 22164.000000
# mean   224679.896003      0.303691     48.407703                    42.120203
# std     72390.704166      0.459861    288.136803                    38.075038
# min    100005.000000      0.000000   -999.000000                     0.000000
# 25%    161858.000000      0.000000     84.995500                    13.425750
# 50%    224412.500000      0.000000    104.558500                    32.165000
# 75%    287699.750000      1.000000    130.189750                    62.188000
# max    349993.000000      1.000000    988.199000                   690.075000
#
#        DER_mass_vis      DER_pt_h  DER_deltaeta_jet_jet  DER_mass_jet_jet  \
# count  22164.000000  22164.000000          22164.000000      22164.000000
# mean      78.925522    126.066343              1.942770        327.179877
# std       48.790879     83.821859              1.469926        317.279844
# min       10.342000      0.777000              0.000000         17.084000
# 25%       54.037250     65.497750              0.714000        123.789750
# 50%       67.991000    108.909000              1.634500        221.334500
# 75%       87.763250    166.420250              2.877000        411.927000
# max     1329.913000    762.806000              7.877000       4062.147000
#
#        DER_prodeta_jet_jet  DER_deltar_tau_lep  ...   PRI_met_phi  \
# count         22164.000000         22164.00000  ...  22164.000000
# mean             -0.153947             1.88462  ...      0.007977
# std               2.867334             0.82726  ...      1.812382
# min             -15.347000             0.37900  ...     -3.141000
# 25%              -1.345250             1.23000  ...     -1.548000
# 50%              -0.015000             1.76700  ...      0.009000
# 75%               1.119250             2.49100  ...      1.562250
# max              14.772000             5.50500  ...      3.141000
#
#        PRI_met_sumet  PRI_jet_num  PRI_jet_leading_pt  PRI_jet_leading_eta  \
# count   22164.000000      22164.0        22164.000000         22164.000000
# mean      414.852725          3.0          123.107808            -0.013810
# std       158.829033          0.0           76.313756             1.573264
# min        22.710000          3.0           31.266000            -4.439000
# 25%       306.536250          3.0           71.515250            -1.179250
# 50%       382.921500          3.0          101.681500            -0.022500
# 75%       486.144500          3.0          150.187250             1.163250
# max      2003.976000          3.0          760.846000             4.476000
#
#        PRI_jet_leading_phi  PRI_jet_subleading_pt  PRI_jet_subleading_eta  \
# count         22164.000000           22164.000000            22164.000000
# mean             -0.001050              71.248456               -0.007787
# std               1.806774              40.126329                1.775354
# min              -3.141000              30.235000               -4.491000
# 25%              -1.559000              46.006750               -1.326000
# 50%              -0.018000              59.799500                0.000000
# 75%               1.578000              82.940750                1.326000
# max               3.141000             721.456000                4.500000
#
#        PRI_jet_subleading_phi  PRI_jet_all_pt
# count            22164.000000    22164.000000
# mean                -0.019144      255.320458
# std                  1.814782      128.454234
# min                 -3.142000       92.812000
# 25%                 -1.593250      167.900500
# 50%                 -0.041000      222.157500
# 75%                  1.548000      304.904000
# max                  3.141000     1633.433000
#
# [8 rows x 32 columns]

# %% [markdown]
# ### Categorize the data and remove columns

# %%
groups = categorize(y, tX, ids)

# %%
for i, (y, tX, ids) in enumerate(groups):
    tX = remove_uniform_col(tX)
    groups[i] = (y, tX, ids)

# %% [markdown]
# ### Cleaning, removing outliers, and standardize (not used)

# %%
non_correlated_cols = []

for i, (y, tX, ids) in enumerate(groups):
    y = change_y(y)
    non_correlated_cols.append(non_correlated_col(tX))
    
    x, mean_x, std_x = clean(tX)
    y, x = remove_outliers(y, x, mean_x, std_x)
    x = x[:, non_correlated_cols[i]]
    # x = standardize(x, mean_x, std_x)
    
    groups[i] = (y, x, ids)

# y_0 = change_y(y_0)
# y_1 = change_y(y_1)
# y_2 = change_y(y_2)
# y_3 = change_y(y_3)

# x_0, mean_x_0, std_x_0 = clean(tX_0)
# y_0, x_0 = remove_outliers(y_0, x_0, mean_x_0, std_x_0)
# x_0 = x_0[:, non_correlated_col_0]
# # x_0 = standardize(x_0, mean_x_0, std_x_0)

# x_1, mean_x_1, std_x_1 = clean(tX_1)
# y_1, x_1 = remove_outliers(y_1, x_1, mean_x_1, std_x_1)
# x_1 = x_1[:, non_correlated_col_1]
# # x_1 = standardize(x_1, mean_x_1, std_x_1)

# x_2, mean_x_2, std_x_2 = clean(tX_2)
# y_2, x_2 = remove_outliers(y_2, x_2, mean_x_2, std_x_2)
# x_2 = x_2[:, non_correlated_col_2]
# # x_2 = standardize(x_2, mean_x_2, std_x_2)

# x_3, mean_x_3, std_x_3 = clean(tX_3)
# y_3, x_3 = remove_outliers(y_3, x_3, mean_x_3, std_x_3)
# x_3 = x_3[:, non_correlated_col_3]
# # x_3 = standardize(x_3, mean_x_3, std_x_3)
for i, (y, tX, ids) in enumerate(groups):
    print(tX.shape)
# Out:
# (93848, 17)
# (70627, 20)
# (43402, 27)
# (18958, 27)

# %% [markdown]
# ### Least squares

# %%
weights = []
y_preds = []

for y, x, ids in groups:
    w, _ = least_squares(y, x)
    y_pred = predict_labels(w, x)
    
    weights.append(w)
    y_preds.append(y_pred)

y_pred = np.concatenate(y_preds)
y_label = np.concatenate([y for (y, _, _) in groups])

accuracy_score(y_pred, y_label)
# Out:
# 0.7691361562369123

# %% [markdown]
# ### Ridge Regression

# %%
groups[0][1]
# Out:
# array([[ 1.43905000e+02,  8.14170000e+01,  8.09430000e+01, ...,
#          3.10820000e+01,  6.00000000e-02,  8.60620000e+01],
#        [ 1.75864000e+02,  1.69150000e+01,  1.34805000e+02, ...,
#          2.72300000e+00, -8.71000000e-01,  5.31310000e+01],
#        [ 1.05594000e+02,  5.05590000e+01,  1.00989000e+02, ...,
#          3.77910000e+01,  2.40000000e-02,  1.29804000e+02],
#        ...,
#        [ 1.20667654e+02,  5.81790000e+01,  6.80830000e+01, ...,
#          4.67370000e+01, -8.67000000e-01,  8.04080000e+01],
#        [ 9.49510000e+01,  1.93620000e+01,  6.88120000e+01, ...,
#          1.21500000e+01,  8.11000000e-01,  1.12718000e+02],
#        [ 1.20667654e+02,  7.27560000e+01,  7.08310000e+01, ...,
#          4.07290000e+01, -1.59600000e+00,  9.94050000e+01]])

# %%
### cross Validation to find lambda
lambdas = np.logspace(-4, 0, 30)
accuracies = []

for y, x, ids in groups:
    accuracy = ridge_cross_validation(y, x, lambdas)
    accuracies.append(accuracy)

# %%
ridge_cross_validation_visualization(lambdas, accuracies)

# %%
### select lambdas with the highest average accuracy
best_lambda = lambdas[np.argmax(np.mean(accuracies, axis=0))]
print(best_lambda)
# Out:
# 0.0002592943797404667

# %%
weights = []
y_preds = []

for y, x, ids in groups:
    w, _ = ridge_regression(y, x, best_lambda)
    y_pred = predict_labels(w, x)
    
    weights.append(w)
    y_preds.append(y_pred)

y_pred = np.concatenate(y_preds)
y_label = np.concatenate([y for (y, _, _) in groups])

accuracy_score(y_pred, y_label)
# Out:
# 0.7692111005797165

# %% [markdown]
# ### Add polynomial basis

# %%
polys = np.arange(1, 13)
accuracies = []

for y, x, ids in groups:
    accuracy = poly_cross_validation(y, x, best_lambda, polys)
    accuracies.append(accuracy)

# %%
poly_cross_validation_visualization(polys, accuracies)

# %%
# we choose a degree of 6 to have substantial performance while avoiding overfitting
for i, (y, x, ids) in enumerate(groups):
    x = build_poly(x, 6)
    groups[i] = (y, x, ids)

# %%
# using ridge regression
weights = []
y_preds = []

for y, x, ids in groups:
    w, _ = ridge_regression(y, x, best_lambda)
    y_pred = predict_labels(w, x)
    
    weights.append(w)
    y_preds.append(y_pred)

y_pred = np.concatenate(y_preds)
y_label = np.concatenate([y for (y, _, _) in groups])

accuracy_score(y_pred, y_label)
# Out:
# 0.8269931888817863

# %%
# using least squares
weights = []
y_preds = []

for y, x, ids in groups:
    w, _ = least_squares(y, x)
    y_pred = predict_labels(w, x)
    
    weights.append(w)
    y_preds.append(y_pred)

y_pred = np.concatenate(y_preds)
y_label = np.concatenate([y for (y, _, _) in groups])

accuracy_score(y_pred, y_label)
# Out:
# 0.8272797407807437

# %% [markdown]
# ### APPYING TO TEST

# %%
DATA_TEST_PATH = '../data/test.csv' # TODO: download train data and supply path here 
y_test, tX_test, ids_test = load_csv_data(DATA_TEST_PATH)

# %%
groups_test = categorize(y_test, tX_test, ids_test)

# %%
for i, (y_test, tX_test, ids_test) in enumerate(groups_test):
    tX_test = remove_uniform_col(tX_test)
    groups_test[i] = (y_test, tX_test, ids_test)

# tXt_0 = remove_uniform_col(tXt_0)
# tXt_1 = remove_uniform_col(tXt_1)
# tXt_2 = remove_uniform_col(tXt_2)
# tXt_3 = remove_uniform_col(tXt_3)

# %%
for i, (y_test, tX_test, ids_test) in enumerate(groups_test):
    y_test = change_y(y_test)
    
    x_test, mean_x_test, std_x_test = clean(tX_test)
    x_test = x_test[:, non_correlated_cols[i]]
    
    groups_test[i] = (y_test, x_test, ids_test)

# %%
# yt_0 = change_y(yt_0)
# yt_1 = change_y(yt_1)
# yt_2 = change_y(yt_2)
# yt_3 = change_y(yt_3)

# xt_0, mean_xt_0, std_xt_0 = clean(tXt_0)
# # yt_0, xt_0 = remove_outliers(yt_0, xt_0, mean_xt_0, std_xt_0)
# xt_0 = xt_0[:, non_correlated_col_0]
# # x_0 = standardize(x_0, mean_x_0, std_x_0)

# xt_1, mean_xt_1, std_xt_1 = clean(tXt_1)
# # yt_1, xt_1 = remove_outliers(yt_1, xt_1, mean_xt_1, std_xt_1)
# xt_1 = xt_1[:, non_correlated_col_1]
# # x_1 = standardize(x_1, mean_x_1, std_x_1)

# xt_2, mean_xt_2, std_xt_2 = clean(tXt_2)
# # yt_2, xt_2 = remove_outliers(yt_2, xt_2, mean_xt_2, std_xt_2)
# xt_2 = xt_2[:, non_correlated_col_2]
# # x_2 = standardize(x_2, mean_x_2, std_x_2)

# xt_3, mean_xt_3, std_xt_3 = clean(tXt_3)
# # yt_3, xt_3 = remove_outliers(yt_3, xt_3, mean_xt_3, std_xt_3)
# xt_3 = xt_3[:, non_correlated_col_3]
# # x_3 = standardize(x_3, mean_x_3, std_x_3)

# %%
for i, (y_test, x_test, ids_test) in enumerate(groups_test):
    x_test = build_poly(x_test, 6)
    groups_test[i] = (y_test, x_test, ids_test)
# xt_0 = build_poly(xt_0, 6)
# xt_1 = build_poly(xt_1, 6)
# xt_2 = build_poly(xt_2, 6)
# xt_3 = build_poly(xt_3, 6)

# %%
y_preds_test = []
for i, (y_test, x_test, ids_test) in enumerate(groups_test):
    y_pred_test = predict_labels(weights[i], x_test)
    y_preds_test.append(y_pred_test)
    
y_pred_test = np.concatenate(y_preds_test)

# %%
y_pred_test.shape
# Out:
# (514380,)

# %%
y_predt_0 = predict_labels(weight_0, xt_0)
y_predt_1 = predict_labels(weight_1, xt_1)
y_predt_2 = predict_labels(weight_2, xt_2)
y_predt_3 = predict_labels(weight_3, xt_3)

# %%
y_predt = np.concatenate((y_predt_0, y_predt_1, y_predt_2, y_predt_3), axis=0)
idst = np.concatenate((idst_0, idst_1, idst_2, idst_3), axis=0)

# %%
y_predt
# Out:
# array([0., 0., 1., ..., 1., 0., 0.])

# %%
y_predt.shape
# Out:
# (568238,)

# %%
ids_test.shape
# Out:
# (568238,)

# %%
OUTPUT_PATH = '../data/sample-submission.csv' # TODO: fill in desired name of output file for submission
y_predt = unchange_y(y_predt)
print(y_predt)
create_csv_submission(idst, y_predt, OUTPUT_PATH)
# Out:
# [-1. -1.  1. ...  1. -1. -1.]

# %%
idst
# Out:
# array([350000, 350002, 350003, ..., 918203, 918223, 918230])
